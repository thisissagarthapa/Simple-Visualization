# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv("richest_person_2015_2024.csv")

# %%
dataset.head(15)
# Out:
#    Year           Person  Net Worth (Billion USD) Source of Wealth
# 0  2015       Bill Gates                     79.2        Microsoft
# 1  2016       Bill Gates                     75.0        Microsoft
# 2  2017       Bill Gates                     86.0        Microsoft
# 3  2018       Jeff Bezos                    112.0           Amazon
# 4  2019       Jeff Bezos                    131.0           Amazon
# 5  2020       Jeff Bezos                    113.0           Amazon
# 6  2021        Elon Musk                    151.0     Tesla/SpaceX
# 7  2022        Elon Musk                    219.0     Tesla/SpaceX
# 8  2023  Bernard Arnault                    211.0             LVMH
# 9  2024  Bernard Arnault                    240.0             LVMH

# %%
dataset["Person_Year"] = dataset["Person"] + " (" + dataset["Year"].astype(str) + ")"

# %%
plt.figure(figsize=(10, 5))
sns.barplot(x="Person_Year", y="Net Worth (Billion USD)", data=dataset, hue="Source of Wealth")
plt.title("Net Worth of Richest Persons by Year (2015-2024)")
plt.ylabel("Net Worth (Billion USD)")
plt.xlabel("Person (Year)")
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.legend(title="Source of Wealth")
plt.show()
